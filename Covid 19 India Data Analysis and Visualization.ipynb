# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import math
import warnings

# %%
# Disable warnings 
warnings.filterwarnings('ignore')

# Read data
corona_data = pd.read_csv("covid19India.csv",index_col=0, parse_dates=True, dayfirst=True)

# Fill all blank values to 0
corona_data = corona_data.fillna(0);

# Convert all numeric columns to int32
corona_data[['Total Confirmed Cases', 'Cured/Discharged/Migrated','Death']] = corona_data[['Total Confirmed Cases', 'Cured/Discharged/Migrated','Death']].astype('int32')

# Active cases = Confirmed cases - (Cured/Dicharged cases + Deaths)
active_cases = corona_data['Total Confirmed Cases'] - corona_data['Cured/Discharged/Migrated'] - corona_data['Death']

# Add Active cases column to the original data
corona_data.insert(2, 'Active Cases', active_cases)

# Calculate daily change, first sort by date and total confirmed cases
corona_data = corona_data.sort_values(by=['State','Date','Total Confirmed Cases'], ascending=True)
corona_data['Daily Change'] = corona_data.groupby('State')['Total Confirmed Cases'].diff(1)
# For the first reported day, daily change = Confirmed cases
corona_data['Daily Change'].fillna(corona_data['Total Confirmed Cases'], inplace=True)
corona_data[['Daily Change']] = corona_data[['Daily Change']].astype('int32')
# Restore sorting
corona_data = corona_data.sort_values(by=['Date','Total Confirmed Cases'], ascending=True)

# Aggregate the state data datewise to get the national numbers
india_data = corona_data.groupby('Date')['Total Confirmed Cases','Active Cases','Daily Change'].sum().reset_index()
# Calculate 5 day moving average
india_data['5 Day Moving Average'] = india_data['Total Confirmed Cases'].rolling(window=5).mean()
# Take latest 30 day data
# Note: Since the index was reset we cannot use last() method here
india_data=india_data.iloc[-30:].reset_index(drop=True)
india_data['5 Day Moving Average'] = india_data['5 Day Moving Average'].astype('int32')

# Remove first three days as not much infomation there
#corona_data=corona_data[3:]
corona_data=corona_data.last('30D')

#india_data = corona_data.groupby('Date')['Total Confirmed Cases','Active Cases','Daily Change'].sum().reset_index()

# Get the data for last reported date
full_latest = corona_data.last('1D')

# Sort descending
full_latest = full_latest.sort_values(by=['Active Cases'], ascending=False)

# Get the data for the top 10 states from the lates reported data
top_ten = full_latest[:10]

# Get the list of top 10 states as per the latest data
state_list_top10 = top_ten['State'].unique()

# Get all historical data for top 10 state
corona_data_top10 = corona_data[corona_data['State'].isin(top_ten['State'].tolist())]

# %% [markdown]
# # The table below summarizes the latest nationwide statistics for India on the last reported date.

# %%
summary_data = full_latest.groupby('Date')['Total Confirmed Cases', 'Daily Change', 'Active Cases', 'Cured/Discharged/Migrated', 'Death'].sum().reset_index()
summary_data['Date'] = summary_data['Date'].dt.strftime('%d %B %Y')
summary_data.style.format({"Total Confirmed Cases": "{:,.0f}", "Daily Change": "{:,.0f}", "Active Cases": "{:,.0f}", "Cured/Discharged/Migrated": "{:,.0f}", "Death": "{:,.0f}"})

styles = [
    dict(selector="th", props=[("font-size", "120%"),
                               ("text-align", "center"),
                              ("font-weight", "normal"),
                              ("color", "grey")]),
    dict(selector="td", props=[("font-size", "250%"),
                               ("text-align", "center"),
                              ("background-color", "white"),
                           ("color", "dodgerblue")]),
    #dict(selector=".row_heading, .blank", props=[("display", "none;")])
]

html = (summary_data.style.set_table_styles(styles))
html
# Out:
# <style type="text/css">
# #T_d1a7b th {
#   font-size: 120%;
#   text-align: center;
#   font-weight: normal;
#   color: grey;
# }
# #T_d1a7b td {
#   font-size: 250%;
#   text-align: center;
#   background-color: white;
#   color: dodgerblue;
# }
# </style>
# <table id="T_d1a7b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1a7b_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_d1a7b_level0_col1" class="col_heading level0 col1" >Total Confirmed Cases</th>
#       <th id="T_d1a7b_level0_col2" class="col_heading level0 col2" >Daily Change</th>
#       <th id="T_d1a7b_level0_col3" class="col_heading level0 col3" >Active Cases</th>
#       <th id="T_d1a7b_level0_col4" class="col_heading level0 col4" >Cured/Discharged/Migrated</th>
#       <th id="T_d1a7b_level0_col5" class="col_heading level0 col5" >Death</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1a7b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d1a7b_row0_col0" class="data row0 col0" >26 July 2020</td>
#       <td id="T_d1a7b_row0_col1" class="data row0 col1" >1385522</td>
#       <td id="T_d1a7b_row0_col2" class="data row0 col2" >48661</td>
#       <td id="T_d1a7b_row0_col3" class="data row0 col3" >467882</td>
#       <td id="T_d1a7b_row0_col4" class="data row0 col4" >885577</td>
#       <td id="T_d1a7b_row0_col5" class="data row0 col5" >32063</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Here's the gradient map for statewise cases on the latest reported data.

# %%
# latest aggregated data
full_latest_grouped = full_latest.groupby('State')['Total Confirmed Cases', 'Daily Change', 'Active Cases', 'Cured/Discharged/Migrated', 'Death'].sum().reset_index()

full_latest_grouped = full_latest_grouped.sort_values(by='Total Confirmed Cases', ascending=False)
full_latest_grouped = full_latest_grouped.reset_index(drop=True)
full_latest_grouped.style.background_gradient(cmap='mako_r')
# Out:
# <style type="text/css">
# #T_dc337_row0_col1, #T_dc337_row0_col2, #T_dc337_row0_col3, #T_dc337_row0_col4, #T_dc337_row0_col5 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# #T_dc337_row1_col1 {
#   background-color: #37689f;
#   color: #f1f1f1;
# }
# #T_dc337_row1_col2 {
#   background-color: #3e3367;
#   color: #f1f1f1;
# }
# #T_dc337_row1_col3 {
#   background-color: #36a3ab;
#   color: #f1f1f1;
# }
# #T_dc337_row1_col4 {
#   background-color: #403974;
#   color: #f1f1f1;
# }
# #T_dc337_row1_col5 {
#   background-color: #48c0ad;
#   color: #000000;
# }
# #T_dc337_row2_col1 {
#   background-color: #36a4ab;
#   color: #f1f1f1;
# }
# #T_dc337_row2_col2, #T_dc337_row10_col4 {
#   background-color: #99ddb6;
#   color: #000000;
# }
# #T_dc337_row2_col3, #T_dc337_row7_col3, #T_dc337_row13_col4 {
#   background-color: #b0e4c1;
#   color: #000000;
# }
# #T_dc337_row2_col4 {
#   background-color: #366da0;
#   color: #f1f1f1;
# }
# #T_dc337_row2_col5 {
#   background-color: #41b8ad;
#   color: #f1f1f1;
# }
# #T_dc337_row3_col1 {
#   background-color: #4bc2ad;
#   color: #000000;
# }
# #T_dc337_row3_col2 {
#   background-color: #366ca0;
#   color: #f1f1f1;
# }
# #T_dc337_row3_col3 {
#   background-color: #359caa;
#   color: #f1f1f1;
# }
# #T_dc337_row3_col4 {
#   background-color: #7cd6af;
#   color: #000000;
# }
# #T_dc337_row3_col5 {
#   background-color: #91dbb4;
#   color: #000000;
# }
# #T_dc337_row4_col1 {
#   background-color: #4dc4ad;
#   color: #000000;
# }
# #T_dc337_row4_col2 {
#   background-color: #312140;
#   color: #f1f1f1;
# }
# #T_dc337_row4_col3 {
#   background-color: #3db3ad;
#   color: #f1f1f1;
# }
# #T_dc337_row4_col4 {
#   background-color: #5bcdad;
#   color: #000000;
# }
# #T_dc337_row4_col5, #T_dc337_row13_col1 {
#   background-color: #b9e6c7;
#   color: #000000;
# }
# #T_dc337_row5_col1 {
#   background-color: #73d4ad;
#   color: #000000;
# }
# #T_dc337_row5_col2 {
#   background-color: #3aadac;
#   color: #f1f1f1;
# }
# #T_dc337_row5_col3, #T_dc337_row6_col1 {
#   background-color: #82d8b0;
#   color: #000000;
# }
# #T_dc337_row5_col4, #T_dc337_row8_col4 {
#   background-color: #65d0ad;
#   color: #000000;
# }
# #T_dc337_row5_col5 {
#   background-color: #a6e1bc;
#   color: #000000;
# }
# #T_dc337_row6_col2 {
#   background-color: #47bfad;
#   color: #000000;
# }
# #T_dc337_row6_col3 {
#   background-color: #94dcb5;
#   color: #000000;
# }
# #T_dc337_row6_col4, #T_dc337_row7_col5 {
#   background-color: #76d5ae;
#   color: #000000;
# }
# #T_dc337_row6_col5, #T_dc337_row9_col1 {
#   background-color: #a9e1bd;
#   color: #000000;
# }
# #T_dc337_row7_col1 {
#   background-color: #88d9b1;
#   color: #000000;
# }
# #T_dc337_row7_col2, #T_dc337_row9_col4, #T_dc337_row12_col4 {
#   background-color: #9edfb8;
#   color: #000000;
# }
# #T_dc337_row7_col4 {
#   background-color: #68d1ad;
#   color: #000000;
# }
# #T_dc337_row8_col1, #T_dc337_row14_col2 {
#   background-color: #8bdab2;
#   color: #000000;
# }
# #T_dc337_row8_col2, #T_dc337_row19_col5, #T_dc337_row21_col5, #T_dc337_row22_col5, #T_dc337_row23_col5, #T_dc337_row24_col2, #T_dc337_row24_col3, #T_dc337_row24_col5, #T_dc337_row25_col5, #T_dc337_row26_col1, #T_dc337_row26_col4, #T_dc337_row26_col5, #T_dc337_row27_col1, #T_dc337_row27_col2, #T_dc337_row27_col3, #T_dc337_row27_col5, #T_dc337_row28_col1, #T_dc337_row28_col4, #T_dc337_row28_col5, #T_dc337_row29_col1, #T_dc337_row29_col3, #T_dc337_row29_col4, #T_dc337_row29_col5, #T_dc337_row30_col1, #T_dc337_row30_col2, #T_dc337_row30_col3, #T_dc337_row30_col4, #T_dc337_row30_col5, #T_dc337_row31_col1, #T_dc337_row31_col3, #T_dc337_row31_col4, #T_dc337_row31_col5, #T_dc337_row32_col1, #T_dc337_row32_col2, #T_dc337_row32_col3, #T_dc337_row32_col4, #T_dc337_row32_col5, #T_dc337_row33_col1, #T_dc337_row33_col2, #T_dc337_row33_col3, #T_dc337_row33_col4, #T_dc337_row33_col5, #T_dc337_row34_col1, #T_dc337_row34_col2, #T_dc337_row34_col3, #T_dc337_row34_col4, #T_dc337_row34_col5 {
#   background-color: #def5e5;
#   color: #000000;
# }
# #T_dc337_row8_col3 {
#   background-color: #b5e5c4;
#   color: #000000;
# }
# #T_dc337_row8_col5, #T_dc337_row17_col1 {
#   background-color: #ceeed7;
#   color: #000000;
# }
# #T_dc337_row9_col2 {
#   background-color: #3fb6ad;
#   color: #f1f1f1;
# }
# #T_dc337_row9_col3, #T_dc337_row11_col1, #T_dc337_row12_col1, #T_dc337_row12_col2 {
#   background-color: #b2e4c2;
#   color: #000000;
# }
# #T_dc337_row9_col5, #T_dc337_row18_col4, #T_dc337_row19_col1, #T_dc337_row20_col3, #T_dc337_row20_col4, #T_dc337_row21_col2 {
#   background-color: #d6f1de;
#   color: #000000;
# }
# #T_dc337_row10_col1 {
#   background-color: #abe2be;
#   color: #000000;
# }
# #T_dc337_row10_col2, #T_dc337_row15_col2 {
#   background-color: #9cdeb7;
#   color: #000000;
# }
# #T_dc337_row10_col3, #T_dc337_row14_col1, #T_dc337_row15_col3 {
#   background-color: #bee8ca;
#   color: #000000;
# }
# #T_dc337_row10_col5, #T_dc337_row12_col3, #T_dc337_row16_col1, #T_dc337_row16_col4 {
#   background-color: #c8ecd2;
#   color: #000000;
# }
# #T_dc337_row11_col2 {
#   background-color: #96ddb5;
#   color: #000000;
# }
# #T_dc337_row11_col3, #T_dc337_row13_col3, #T_dc337_row14_col3 {
#   background-color: #c4eacf;
#   color: #000000;
# }
# #T_dc337_row11_col4 {
#   background-color: #a1dfb9;
#   color: #000000;
# }
# #T_dc337_row11_col5, #T_dc337_row15_col5, #T_dc337_row18_col5, #T_dc337_row20_col5, #T_dc337_row23_col1, #T_dc337_row23_col3, #T_dc337_row23_col4, #T_dc337_row24_col1, #T_dc337_row24_col4, #T_dc337_row25_col1, #T_dc337_row25_col3, #T_dc337_row25_col4, #T_dc337_row26_col2, #T_dc337_row26_col3, #T_dc337_row27_col4, #T_dc337_row28_col2, #T_dc337_row28_col3, #T_dc337_row29_col2, #T_dc337_row31_col2 {
#   background-color: #dcf4e3;
#   color: #000000;
# }
# #T_dc337_row12_col5, #T_dc337_row18_col3 {
#   background-color: #d0efd9;
#   color: #000000;
# }
# #T_dc337_row13_col2, #T_dc337_row14_col4 {
#   background-color: #b7e6c5;
#   color: #000000;
# }
# #T_dc337_row13_col5 {
#   background-color: #c0e9cc;
#   color: #000000;
# }
# #T_dc337_row14_col5, #T_dc337_row21_col3, #T_dc337_row22_col1, #T_dc337_row22_col2, #T_dc337_row22_col3, #T_dc337_row22_col4, #T_dc337_row25_col2 {
#   background-color: #daf3e1;
#   color: #000000;
# }
# #T_dc337_row15_col1, #T_dc337_row16_col3, #T_dc337_row17_col2 {
#   background-color: #c6ebd1;
#   color: #000000;
# }
# #T_dc337_row15_col4, #T_dc337_row17_col4 {
#   background-color: #caedd4;
#   color: #000000;
# }
# #T_dc337_row16_col2, #T_dc337_row20_col2 {
#   background-color: #c2e9cd;
#   color: #000000;
# }
# #T_dc337_row16_col5, #T_dc337_row17_col5, #T_dc337_row18_col1, #T_dc337_row19_col4 {
#   background-color: #d4f1dc;
#   color: #000000;
# }
# #T_dc337_row17_col3 {
#   background-color: #d2f0db;
#   color: #000000;
# }
# #T_dc337_row18_col2, #T_dc337_row19_col2 {
#   background-color: #ccedd6;
#   color: #000000;
# }
# #T_dc337_row19_col3, #T_dc337_row20_col1, #T_dc337_row21_col1, #T_dc337_row21_col4, #T_dc337_row23_col2 {
#   background-color: #d8f2e0;
#   color: #000000;
# }
# </style>
# <table id="T_dc337">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc337_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_dc337_level0_col1" class="col_heading level0 col1" >Total Confirmed Cases</th>
#       <th id="T_dc337_level0_col2" class="col_heading level0 col2" >Daily Change</th>
#       <th id="T_dc337_level0_col3" class="col_heading level0 col3" >Active Cases</th>
#       <th id="T_dc337_level0_col4" class="col_heading level0 col4" >Cured/Discharged/Migrated</th>
#       <th id="T_dc337_level0_col5" class="col_heading level0 col5" >Death</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc337_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dc337_row0_col0" class="data row0 col0" >Maharashtra</td>
#       <td id="T_dc337_row0_col1" class="data row0 col1" >366368</td>
#       <td id="T_dc337_row0_col2" class="data row0 col2" >9251</td>
#       <td id="T_dc337_row0_col3" class="data row0 col3" >145785</td>
#       <td id="T_dc337_row0_col4" class="data row0 col4" >207194</td>
#       <td id="T_dc337_row0_col5" class="data row0 col5" >13389</td>
#     </tr>
#     <tr>
#       <th id="T_dc337_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dc337_row1_col0" class="data row1 col0" >Tamil Nadu</td>
#       <td id="T_dc337_row1_col1" class="data row1 col1" >206737</td>
#       <td id="T_d

# %% [markdown]
# # Here's the total confirmed and active cases trend in India for last 30 days.

# %%
import matplotlib.ticker as ticker

sns.set_style("whitegrid")#, {'xtick.bottom': True, 'xtick.color': '.6'}
sns.set_context("talk", rc={"grid.linewidth": 0.0})

fig, ax1 = plt.subplots(figsize=(16,10))
ax2 = ax1.twinx()

g = sns.lineplot(x=india_data.index, y='Total Confirmed Cases', legend="brief", color=sns.xkcd_rgb["dark pink"],
                  data=india_data, ax=ax1)

g = sns.lineplot(x=india_data.index, y='Active Cases', legend="brief", color="teal", 
                  data=india_data, ax=ax1)

sns.barplot(x=india_data.index, y='Daily Change', color="lightgray", alpha=0.3,
            data=india_data, ax=ax2)

ax1.set_xlabel('Date')
ax1.set_ylabel('Number of Cases')
ax1.yaxis.label.set_color('teal')
ax1.tick_params(axis='y', colors='teal')

ax2.yaxis.label.set_color('gray')
ax2.tick_params(axis='y', colors='gray')

x_labels = india_data['Date'].dt.strftime('%b %d').copy()
for i in range(len(x_labels)):
    if (i % 7) != 0:
        x_labels[i] = ''


ax1.xaxis.set_major_formatter(ticker.FixedFormatter(x_labels))

plt.title('Total Confirmed and Active Cases Trend (Last 30 Days)')
ax1.legend(['Total Confirmed Cases','Active Cases'])

plt.show()

# %% [markdown]
# # The plot below shows doubling rate of Total Confirmed Cases over 5 day moving average for last 30 days

# %%
def get_doubling_rate_plot_2(data, doubling_rate):
    y_max = data['Total Confirmed Cases'].max()
    y_min = data['Total Confirmed Cases'].min()
    x_min = data.index.min()
    x_max = data.index.max()
    
    x_d1 = np.empty(0)
    y_d1 = np.empty(0)
    y_d1 = np.append(y_d1, y_min)
    x_d1 = np.append(x_d1, data.index[0]) 
    y_val = y_d1[0]
    k = 0
    while (y_val < y_max):
        y_val = 2 * y_val
        k = k + 1

    y_d1 = np.append(y_d1, y_val/2)
    x = (k-1)*doubling_rate
    if (x > len(india_data)):
        x = len(india_data) - 1
    x_d1 = np.append(x_d1, data.index[x]) 

    return x_d1, y_d1

# %%
def plot_doubling_rate(data, doubling_rate, plot):
    y_max = float(data['Total Confirmed Cases'].max())
    y_min = float(data['5 Day Moving Average'].min())
    x_min = float(data.index.min())
    x_max = float(data.index.max())

    x_d1 = np.empty(0)
    y_d1 = np.empty(0)
    x_d1 = np.append(x_d1, x_min) 
    y_d1 = np.append(y_d1, y_min)

    x_2 = doubling_rate * (math.log2(y_max)-math.log2(y_min))
    if (x_2 > x_max):
        y_2 = 2 ** ((x_max/doubling_rate) + math.log2(y_min))
        x_2 = x_max
        #x_2 = doubling_rate * (math.log2(y_2)-math.log2(y_min))
    else:
        y_2 = y_max

    x_d1 = np.append(x_d1, int(x_2))
    y_d1 = np.append(y_d1, int(y_2))

    annotation = str(doubling_rate) + " Days"
    line_index = len(plot.lines)
    plot = sns.lineplot(x=x_d1, y=y_d1, color="grey")
    plot.lines[line_index].set_linestyle("-.")
    plot.annotate(annotation, xy=(x_d1[1], y_d1[1]),color="grey")

# %%
import matplotlib.ticker as ticker
import numpy as np

sns.set_style("whitegrid")#, {'xtick.bottom': True, 'xtick.color': '.6'}
sns.set_context("talk", rc={"grid.linewidth": 0.3})#sns.set(style="ticks", rc={"lines.linewidth": 0.7})

plt.figure(figsize=(16, 10))

plot = sns.lineplot(x=india_data.index, y='5 Day Moving Average', hue=None, color=sns.xkcd_rgb["tangerine"],
                  data=india_data)

sns.set_context(rc={"grid.linewidth": 0.3, "lines.linewidth": 0.8})

# Doubling rate = 14 days
plot_doubling_rate(india_data, 14, plot)

# Doubling rate = 15 days
plot_doubling_rate(india_data, 15, plot)

# Doubling rate = 16 days
plot_doubling_rate(india_data, 16, plot)

x1_labels = india_data['Date'].dt.strftime('%b %d').copy()
for m in range(len(x1_labels)):
    if (m % 7) != 0:
        x1_labels[m] = ''

plot.xaxis.set_major_locator(ticker.FixedLocator(india_data.index))
plot.xaxis.set_major_formatter(ticker.FixedFormatter(x1_labels))

#plt.title('5 Day Moving Average of Total Confirmed Cases and Doubling Rate(Last 30 Days)')
plt.title('Doubling Rate of Total Confirmed Cases over 5 Day Moving Average(Last 30 Days)')
plt.xlabel('Date')
plt.ylabel('Total Confirmed Cases')
plt.show()

# %% [markdown]
# # The pie chart below shows the percentage of active cases in each state based on the data reported on the last day.

# %%
# Consilidate rest of the states apart from top 10 into a single entry called 'Others'
others_confirmed_sum = full_latest[10:]['Total Confirmed Cases'].sum()
others_active_sum = full_latest[10:]['Active Cases'].sum()

others_data = pd.DataFrame({'State':['Others'], 
                    'Total Confirmed Cases':others_confirmed_sum,  
                    'Active Cases':others_active_sum,
                    'Cured/Discharged/Migrated':0,
                    'Death':0}, index=[top_ten.index[0]]) 

# Add the 'Others' entry to top 10
top_ten_with_others = top_ten.append(others_data)

# %%
# Plot pie chart to see the percentage of active cases statewise
palette=sns.color_palette("Blues_r", n_colors=11)

# Plot
plt.figure(figsize=(16, 10))
plt.pie(top_ten_with_others['Active Cases'], labels=top_ten_with_others['State'], colors=palette,
autopct='%1.1f%%', shadow=False, startangle=90)

plt.title('Percentage of Active Cases by State')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Statewise total confirmed cases for last 30 days on logarithmic scale to identify states with higher rate of increase.

# %%
# Sort descending
corona_data = corona_data.sort_values(by=['State','Date'])
corona_data = corona_data.reset_index()

sns.set_style("whitegrid")
sns.set_context("talk", rc={"grid.linewidth": 0.3})
g = sns.FacetGrid(corona_data, col="State", col_wrap=5, height=5)
g = g.map(plt.plot, "Date", "Total Confirmed Cases", color=sns.xkcd_rgb["teal"],).set(yscale ='log')
xlabels = [''  for x in range(30)]

# Hide x axis gridlines
for ax in g.axes:
    ax.xaxis.grid(False)
    ax.set_xticklabels(xlabels)
    ax.set(xlabel=None)
